# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Обработаем-living_area,-ceiling_height" data-toc-modified-id="Обработаем-living_area,-ceiling_height-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Обработаем living_area, ceiling_height</a></span></li><li><span><a href="#Обработаем-параметр-studio" data-toc-modified-id="Обработаем-параметр-studio-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Обработаем параметр studio</a></span><ul class="toc-item"><li><span><a href="#Проведем-дополнительный-анализ-студий" data-toc-modified-id="Проведем-дополнительный-анализ-студий-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Проведем дополнительный анализ студий</a></span></li></ul></li><li><span><a href="#Обработаем-параметр-is_apartment" data-toc-modified-id="Обработаем-параметр-is_apartment-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Обработаем параметр is_apartment</a></span></li><li><span><a href="#Обработаем-параметр-locality_name" data-toc-modified-id="Обработаем-параметр-locality_name-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Обработаем параметр locality_name</a></span></li><li><span><a href="#Обработаем-параметр-balcony" data-toc-modified-id="Обработаем-параметр-balcony-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Обработаем параметр balcony</a></span></li><li><span><a href="#Обработаем-параметр-airports_nearest" data-toc-modified-id="Обработаем-параметр-airports_nearest-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Обработаем параметр airports_nearest</a></span></li><li><span><a href="#Обработаем-параметр-floors_total" data-toc-modified-id="Обработаем-параметр-floors_total-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Обработаем параметр floors_total</a></span></li><li><span><a href="#Обработаем-параметр-days_exposition" data-toc-modified-id="Обработаем-параметр-days_exposition-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Обработаем параметр days_exposition</a></span></li><li><span><a href="#Обработаем-параметр-first_day_exposition" data-toc-modified-id="Обработаем-параметр-first_day_exposition-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>Обработаем параметр first_day_exposition</a></span></li><li><span><a href="#Обработаем-параметр-parks_around3000" data-toc-modified-id="Обработаем-параметр-parks_around3000-2.10"><span class="toc-item-num">2.10&nbsp;&nbsp;</span>Обработаем параметр parks_around3000</a></span></li><li><span><a href="#Обработаем-параметр-ponds_around3000" data-toc-modified-id="Обработаем-параметр-ponds_around3000-2.11"><span class="toc-item-num">2.11&nbsp;&nbsp;</span>Обработаем параметр ponds_around3000</a></span></li><li><span><a href="#Обработаем-параметр-parks_nearest,-ponds_nearest" data-toc-modified-id="Обработаем-параметр-parks_nearest,-ponds_nearest-2.12"><span class="toc-item-num">2.12&nbsp;&nbsp;</span>Обработаем параметр parks_nearest, ponds_nearest</a></span></li><li><span><a href="#Произведем-категоризацию-данных" data-toc-modified-id="Произведем-категоризацию-данных-2.13"><span class="toc-item-num">2.13&nbsp;&nbsp;</span>Произведем категоризацию данных</a></span><ul class="toc-item"><li><span><a href="#Обработаем-параметр-living_area" data-toc-modified-id="Обработаем-параметр-living_area-2.13.1"><span class="toc-item-num">2.13.1&nbsp;&nbsp;</span>Обработаем параметр living_area</a></span></li><li><span><a href="#Обработаем-airports_nearest" data-toc-modified-id="Обработаем-airports_nearest-2.13.2"><span class="toc-item-num">2.13.2&nbsp;&nbsp;</span>Обработаем airports_nearest</a></span></li><li><span><a href="#Обработаем-city_centers_nearest" data-toc-modified-id="Обработаем-city_centers_nearest-2.13.3"><span class="toc-item-num">2.13.3&nbsp;&nbsp;</span>Обработаем city_centers_nearest</a></span></li></ul></li><li><span><a href="#Создадим-общую-функцию,-с-помощью-которой-будем-заполнять-пропуски" data-toc-modified-id="Создадим-общую-функцию,-с-помощью-которой-будем-заполнять-пропуски-2.14"><span class="toc-item-num">2.14&nbsp;&nbsp;</span>Создадим общую функцию, с помощью которой будем заполнять пропуски</a></span><ul class="toc-item"><li><span><a href="#Заполним-пропуски-в-'living_area'" data-toc-modified-id="Заполним-пропуски-в-'living_area'-2.14.1"><span class="toc-item-num">2.14.1&nbsp;&nbsp;</span>Заполним пропуски в 'living_area'</a></span></li><li><span><a href="#Заполним-пропуски-в-'airports_nearest'" data-toc-modified-id="Заполним-пропуски-в-'airports_nearest'-2.14.2"><span class="toc-item-num">2.14.2&nbsp;&nbsp;</span>Заполним пропуски в 'airports_nearest'</a></span></li><li><span><a href="#Заполним-пропуски-в-'city_centers_nearest'" data-toc-modified-id="Заполним-пропуски-в-'city_centers_nearest'-2.14.3"><span class="toc-item-num">2.14.3&nbsp;&nbsp;</span>Заполним пропуски в 'city_centers_nearest'</a></span></li></ul></li><li><span><a href="#Изменение-типов-данных" data-toc-modified-id="Изменение-типов-данных-2.15"><span class="toc-item-num">2.15&nbsp;&nbsp;</span>Изменение типов данных</a></span></li><li><span><a href="#Удаление-дубликатов" data-toc-modified-id="Удаление-дубликатов-2.16"><span class="toc-item-num">2.16&nbsp;&nbsp;</span>Удаление дубликатов</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.17"><span class="toc-item-num">2.17&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span><ul class="toc-item"><li><span><a href="#Цена-квадратного-метра" data-toc-modified-id="Цена-квадратного-метра-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Цена квадратного метра</a></span></li><li><span><a href="#День-недели,-месяц-и-год-публикации-объявления" data-toc-modified-id="День-недели,-месяц-и-год-публикации-объявления-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>День недели, месяц и год публикации объявления</a></span></li><li><span><a href="#Этаж-квартиры" data-toc-modified-id="Этаж-квартиры-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Этаж квартиры</a></span></li><li><span><a href="#Cоотношение-жилой-и-общей-площади" data-toc-modified-id="Cоотношение-жилой-и-общей-площади-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Cоотношение жилой и общей площади</a></span></li><li><span><a href="#Отношение-площади-кухни-к-общей" data-toc-modified-id="Отношение-площади-кухни-к-общей-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Отношение площади кухни к общей</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Проанализируем-выбросы-в-столбцах." data-toc-modified-id="Проанализируем-выбросы-в-столбцах.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Проанализируем выбросы в столбцах.</a></span><ul class="toc-item"><li><span><a href="#Столбец-'last_price'" data-toc-modified-id="Столбец-'last_price'-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Столбец 'last_price'</a></span></li><li><span><a href="#Столбец-'ceiling_height'" data-toc-modified-id="Столбец-'ceiling_height'-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Столбец 'ceiling_height'</a></span></li><li><span><a href="#Столбец-'days_exposition'" data-toc-modified-id="Столбец-'days_exposition'-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Столбец 'days_exposition'</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Проведем-исследовательский-анализ-данных" data-toc-modified-id="Проведем-исследовательский-анализ-данных-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Проведем исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Построим-гистограмму-по-значениям-из-столбца-'total_area'" data-toc-modified-id="Построим-гистограмму-по-значениям-из-столбца-'total_area'-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Построим гистограмму по значениям из столбца 'total_area'</a></span></li><li><span><a href="#Построим-гистограмму-по-значениям-из-столбца-'last_price'" data-toc-modified-id="Построим-гистограмму-по-значениям-из-столбца-'last_price'-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Построим гистограмму по значениям из столбца 'last_price'</a></span></li><li><span><a href="#Построим-гистограмму-по-значениям-из-столбца-'rooms'" data-toc-modified-id="Построим-гистограмму-по-значениям-из-столбца-'rooms'-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Построим гистограмму по значениям из столбца 'rooms'</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.2.3.1"><span class="toc-item-num">4.2.3.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Построим-гистограмму-по-значениям-из-столбца-'ceiling_height'" data-toc-modified-id="Построим-гистограмму-по-значениям-из-столбца-'ceiling_height'-4.2.4"><span class="toc-item-num">4.2.4&nbsp;&nbsp;</span>Построим гистограмму по значениям из столбца 'ceiling_height'</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.2.4.1"><span class="toc-item-num">4.2.4.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Построим-гистограмму-по-значениям-из-столбца-'first_day_exposition'" data-toc-modified-id="Построим-гистограмму-по-значениям-из-столбца-'first_day_exposition'-4.2.5"><span class="toc-item-num">4.2.5&nbsp;&nbsp;</span>Построим гистограмму по значениям из столбца 'first_day_exposition'</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.2.5.1"><span class="toc-item-num">4.2.5.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Построим-гистограмму-по-значениям-из-столбца-'days_exposition'" data-toc-modified-id="Построим-гистограмму-по-значениям-из-столбца-'days_exposition'-4.2.6"><span class="toc-item-num">4.2.6&nbsp;&nbsp;</span>Построим гистограмму по значениям из столбца 'days_exposition'</a></span><ul class="toc-item"><li><span><a href="#Вывод-по-гистограмме" data-toc-modified-id="Вывод-по-гистограмме-4.2.6.1"><span class="toc-item-num">4.2.6.1&nbsp;&nbsp;</span>Вывод по гистограмме</a></span></li><li><span><a href="#Посчитаем-медиану-и-среднее-значение" data-toc-modified-id="Посчитаем-медиану-и-среднее-значение-4.2.6.2"><span class="toc-item-num">4.2.6.2&nbsp;&nbsp;</span>Посчитаем медиану и среднее значение</a></span></li></ul></li></ul></li><li><span><a href="#Изучим-кореляцию-цен-от-других-параметров" data-toc-modified-id="Изучим-кореляцию-цен-от-других-параметров-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Изучим кореляцию цен от других параметров</a></span><ul class="toc-item"><li><span><a href="#Зависимость-цены-от-параметров-квартиры" data-toc-modified-id="Зависимость-цены-от-параметров-квартиры-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Зависимость цены от параметров квартиры</a></span></li><li><span><a href="#Зависимость-цены-от-даты-размещения-объявления" data-toc-modified-id="Зависимость-цены-от-даты-размещения-объявления-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Зависимость цены от даты размещения объявления</a></span></li></ul></li><li><span><a href="#Проанализируем-среднюю-цену-за-метр-в-топ-10-городах" data-toc-modified-id="Проанализируем-среднюю-цену-за-метр-в-топ-10-городах-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Проанализируем среднюю цену за метр в топ-10 городах</a></span></li><li><span><a href="#Изучение-предложений-квартир-в-СПБ" data-toc-modified-id="Изучение-предложений-квартир-в-СПБ-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Изучение предложений квартир в СПБ</a></span><ul class="toc-item"><li><span><a href="#Добавим-столбец-с-расстоянием-до-центра-в-км" data-toc-modified-id="Добавим-столбец-с-расстоянием-до-центра-в-км-4.5.1"><span class="toc-item-num">4.5.1&nbsp;&nbsp;</span>Добавим столбец с расстоянием до центра в км</a></span></li></ul></li><li><span><a href="#Найдем-корреляцию-для-недвижимости-в-центре-Питера" data-toc-modified-id="Найдем-корреляцию-для-недвижимости-в-центре-Питера-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Найдем корреляцию для недвижимости в центре Питера</a></span><ul class="toc-item"><li><span><a href="#Посморим-распределения-по-отдельным-велечинам" data-toc-modified-id="Посморим-распределения-по-отдельным-велечинам-4.6.1"><span class="toc-item-num">4.6.1&nbsp;&nbsp;</span>Посморим распределения по отдельным велечинам</a></span></li><li><span><a href="#Выводы:" data-toc-modified-id="Выводы:-4.6.2"><span class="toc-item-num">4.6.2&nbsp;&nbsp;</span>Выводы:</a></span></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекc Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# ## Изучение данных из файла

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/datasets/real_estate_data.csv',sep='\t')
pd.set_option("display.max_rows", 35)
pd.set_option("display.precision", 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# Заметим, что всего в фрейме 23699 строк, поэтому столбцы:ceiling_height, floors_total, is_apartment,kitchen_area ,balcony,locality_name,airports_nearest ,cityCenters_nearest, parks_around3000,parks_nearest,ponds_around3000,ponds_nearest,days_exposition содержат пропуски

# %%
df.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'cityCenters_nearest',
#        'parks_around3000', 'parks_nearest', 'ponds_around3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %% [markdown]
# Заметим, что столбец 'cityCenters_nearest' назван некорректно.

# %%
df.rename(columns = {'cityCenters_nearest' : 'city_centers_nearest'}, inplace = True )
df.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'city_centers_nearest',
#        'parks_around3000', 'parks_nearest', 'ponds_around3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %% [markdown]
# Теперь все столбцы названы корректно.

# %%
df.describe().T
# Out:
#                         count         mean          std      min         25%  \
# total_images          23699.0  9.85848e+00  5.68253e+00      0.0        6.00
# last_price            23699.0  6.54155e+06  1.08870e+07  12190.0  3400000.00
# total_area            23699.0  6.03487e+01  3.56541e+01     12.0       40.00
# rooms                 23699.0  2.07064e+00  1.07840e+00      0.0        1.00
# ceiling_height        14504.0  2.77150e+00  1.26106e+00      1.0        2.52
# floors_total          23613.0  1.06738e+01  6.59717e+00      1.0        5.00
# living_area           21796.0  3.44579e+01  2.20304e+01      2.0       18.60
# floor                 23699.0  5.89236e+00  4.88525e+00      1.0        2.00
# kitchen_area          21421.0  1.05698e+01  5.90544e+00      1.3        7.00
# balcony               12180.0  1.15008e+00  1.07130e+00      0.0        0.00
# airports_nearest      18157.0  2.87937e+04  1.26309e+04      0.0    18585.00
# ...

# %% [markdown]
# Заметим, что в данных присутствуют аномалии.
#
# Минимальное значение в столбце rooms = 0
#
# Минимальное значение в столбце ceiling_height = 0
#
# Минимальное значение в столбце floors_tota = 1
#
# Минимальное значение в столбце living_area = 2
#
# Минимальное значение в столбце kitchen_area = 1.3
#
# Минимальное значение в столбце airports_nearest = 0

# %% [markdown]
# ### Вывод

# %% [markdown]
# В данный содержится большое количество аномалий и пропусков.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Обработаем living_area, ceiling_height

# %% [markdown]
# Площадь квартир социального использования государственного и муниципального жилищных фондов согласно ЖК РФ должна быть не менее:
#
# ► Общей жилой комнаты в однокомнатной квартире — 14 м².
#
# ► Общей жилой комнаты в квартирах с числом комнат две и более — 16 м².
#
# ► Спальни — 8 м² (на двух человек — 10 м²); кухни — 8 м².
#
# ► Кухонной зоны в кухне-столовой — 6 м².
#
# ► В однокомнатных квартирах допускается проектировать кухни или кухни-ниши площадью не менее 5 м².
#
# ► Высота жилых помещений от пола до потолка должна быть не менее 2,5 м
#
# ► Высота внутриквартирных коридоров должна быть не менее 2,1 м.

# %%
def min_living_area(row):
    if row["rooms"] <= 1 and row['living_area'] < 14:
        row['total_area'] += 14 - row['living_area']
        row['living_area'] = 14
    elif row["rooms"] > 1 and row['living_area'] < 16:
        row['total_area'] += 16 - row['living_area']
        row['living_area'] = 16
    return row

# %%
df = df.apply(min_living_area, axis = 1)

# %%
df['ceiling_height'] = df['ceiling_height'].where(~((df['ceiling_height'].isnull()) | (df['ceiling_height'] <2.1)),2.1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        23699 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# ### Обработаем параметр studio

# %%
df.query('rooms == 1 and studio != True')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 1                 7   3350000.0       40.40  2018-12-04T00:00:00      1
# 5                10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6                 6   3700000.0       40.70  2017-11-02T00:00:00      1
# 8                20   2900000.0       33.16  2018-05-23T00:00:00      1
# 10                5   5050000.0       39.60  2017-11-16T00:00:00      1
# ...             ...         ...         ...                  ...    ...
# 23686             8   3300000.0       31.00  2017-04-29T00:00:00      1
# 23687             6   3200000.0       39.00  2017-12-16T00:00:00      1
# 23689            13   3550000.0       35.30  2018-02-28T00:00:00      1
# 23692             2   1350000.0       30.00  2017-07-07T00:00:00      1
# 23698             4   1350000.0       34.00  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %% [markdown]
# Поверим равно ли значение квартир, в которых 0 комнат с квартирами-студиями

# %%
result = (len(df.query('rooms == 0')) == len(df.query('rooms == 0 and studio == True')))

if result == True:
    print('Все верно!')
else:
    print('Результат отрицательный')
# Out:
# Результат отрицательный

# %% [markdown]
# #### Проведем дополнительный анализ студий

# %%
df.query('rooms==0 and studio == False')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 349               4   2320000.0        25.0  2017-09-27T00:00:00      0
# 508               0   3375000.0        34.4  2017-03-28T00:00:00      0
# 780               9   2600000.0        26.1  2018-02-20T00:00:00      0
# 839              14   1900000.0        35.0  2017-04-14T00:00:00      0
# 946               5   2200000.0        23.0  2016-09-27T00:00:00      0
# ...             ...         ...         ...                  ...    ...
# 21299            13   2450000.0        28.5  2017-11-22T00:00:00      0
# 21628             9   3900000.0        34.0  2017-03-18T00:00:00      0
# 22573             8   2250000.0        24.0  2017-09-28T00:00:00      0
# 23442             0   2500000.0        27.7  2017-09-28T00:00:00      0
# 23592            10   1450000.0        29.0  2017-11-11T00:00:00      0
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %% [markdown]
# Заметим, что в данных есть квартиры, которые не являются студиями, но при этом количество комнат равно нулю и данные по кухне отсутсувуют. Значит наиболее реальный вариант изменения данной аномалии перевод флага студии из False в True

# %%
df["kitchen_area"].isnull().sum()
# Out:
# 2278

# %%
df[(df["kitchen_area"].isnull())]['studio'].sum()
# Out:
# 149

# %% [markdown]
# Заметим, что количество пропусков по кухне больше, чем количество пропусков по кухне у студии.
#
# Кварти́ра-сту́дия — тип квартиры, основным отличием которого является отсутствие внутренних перегородок между кухней и жилыми комнатами или комнатой.
#
# Следователь, по определению можно сделать вывод, что там где нет кухни, там студия

# %%
df.loc[df["kitchen_area"].isnull(),'studio'] = True

# %% [markdown]
# Заменим значения площади кухни у студии на ноль

# %%
df["kitchen_area"] = df["kitchen_area"].where(~df["kitchen_area"].isnull(),0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        23699 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          23699 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# ### Обработаем параметр is_apartment

# %% [markdown]
# Разница между апартаментами и обычно квартирой заключается только в налогообложения. Поэтому логичнее будет заменить пропуски значениями False

# %%
df['is_apartment'] = df['is_apartment'].where(~df['is_apartment'].isnull(), False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        23699 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          23699 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# ### Обработаем параметр locality_name

# %% [markdown]
# Восстановить название города невозможно, поэтому просто заменим пропуски на 'unknown'

# %%
df['locality_name'] = df['locality_name'].where(~df['locality_name'].isnull(), 'unknown')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        23699 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          23699 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23699 non-null  object
# ...

# %% [markdown]
# ### Обработаем параметр balcony

# %%
df['balcony'].fillna(0,inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        23699 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          23699 non-null  float64
#  13  balcony               23699 non-null  float64
#  14  locality_name         23699 non-null  object
# ...

# %% [markdown]
# ### Обработаем параметр airports_nearest

# %%
df['airports_nearest']
# Out:
# 0        18863.0
# 1        12817.0
# 2        21741.0
# 3        28098.0
# 4        31856.0
#           ...
# 23694    24665.0
# 23695        NaN
# 23696        NaN
# 23697    39140.0
# 23698        NaN
# Name: airports_nearest, Length: 23699, dtype: float64

# %% [markdown]
# ### Обработаем параметр floors_total

# %%
print(df['floors_total'].isnull().sum())
# Out:
# 86

# %%
df.dropna(subset=['floors_total'],inplace = True,axis = 0 )

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23613 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23613 non-null  int64
#  1   last_price            23613 non-null  float64
#  2   total_area            23613 non-null  float64
#  3   first_day_exposition  23613 non-null  object
#  4   rooms                 23613 non-null  int64
#  5   ceiling_height        23613 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21743 non-null  float64
#  8   floor                 23613 non-null  int64
#  9   is_apartment          23613 non-null  object
#  10  studio                23613 non-null  bool
#  11  open_plan             23613 non-null  bool
#  12  kitchen_area          23613 non-null  float64
#  13  balcony               23613 non-null  float64
#  14  locality_name         23613 non-null  object
# ...

# %% [markdown]
# Так как предугадать сколько этаже в доме невозможно, поэтому удалим их, чтобы в дальнейшем не было ошибок в анализе

# %% [markdown]
# Большинство параметров получилось имправить применив аналитические действия, но, к сожалению, в данных присутствуют пропуски, которые невозможно восстановить, поэтому для дальнейшей работы мы их удалили

# %% [markdown]
# ### Обработаем параметр days_exposition

# %%
df.dropna(subset=['days_exposition'],inplace = True,axis = 0 )

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20441 entries, 1 to 23697
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          20441 non-null  int64
#  1   last_price            20441 non-null  float64
#  2   total_area            20441 non-null  float64
#  3   first_day_exposition  20441 non-null  object
#  4   rooms                 20441 non-null  int64
#  5   ceiling_height        20441 non-null  float64
#  6   floors_total          20441 non-null  float64
#  7   living_area           18766 non-null  float64
#  8   floor                 20441 non-null  int64
#  9   is_apartment          20441 non-null  object
#  10  studio                20441 non-null  bool
#  11  open_plan             20441 non-null  bool
#  12  kitchen_area          20441 non-null  float64
#  13  balcony               20441 non-null  float64
#  14  locality_name         20441 non-null  object
# ...

# %% [markdown]
# ### Обработаем параметр first_day_exposition

# %%
df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'],format = '%Y-%m-%dT%H:%M:%S')

# %%
print(df['first_day_exposition'])
# Out:
# 1       2018-12-04
# 2       2015-08-20
# 3       2015-07-24
# 4       2018-06-19
# 5       2018-09-10
#            ...
# 23691   2016-10-13
# 23692   2017-07-07
# 23693   2016-08-05
# 23695   2018-01-15
# 23697   2017-03-28
# Name: first_day_exposition, Length: 20441, dtype: datetime64[ns]

# %% [markdown]
# ### Обработаем параметр parks_around3000

# %%
df['parks_around3000'] = df['parks_around3000'].fillna(df['parks_around3000'].median())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20441 entries, 1 to 23697
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          20441 non-null  int64
#  1   last_price            20441 non-null  float64
#  2   total_area            20441 non-null  float64
#  3   first_day_exposition  20441 non-null  datetime64[ns]
#  4   rooms                 20441 non-null  int64
#  5   ceiling_height        20441 non-null  float64
#  6   floors_total          20441 non-null  float64
#  7   living_area           18766 non-null  float64
#  8   floor                 20441 non-null  int64
#  9   is_apartment          20441 non-null  object
#  10  studio                20441 non-null  bool
#  11  open_plan             20441 non-null  bool
#  12  kitchen_area          20441 non-null  float64
#  13  balcony               20441 non-null  float64
# ...

# %% [markdown]
# ### Обработаем параметр ponds_around3000

# %%
df['ponds_around3000'] = df['ponds_around3000'].fillna(df['ponds_around3000'].median())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20441 entries, 1 to 23697
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          20441 non-null  int64
#  1   last_price            20441 non-null  float64
#  2   total_area            20441 non-null  float64
#  3   first_day_exposition  20441 non-null  datetime64[ns]
#  4   rooms                 20441 non-null  int64
#  5   ceiling_height        20441 non-null  float64
#  6   floors_total          20441 non-null  float64
#  7   living_area           18766 non-null  float64
#  8   floor                 20441 non-null  int64
#  9   is_apartment          20441 non-null  object
#  10  studio                20441 non-null  bool
#  11  open_plan             20441 non-null  bool
#  12  kitchen_area          20441 non-null  float64
#  13  balcony               20441 non-null  float64
# ...

# %% [markdown]
# ### Обработаем параметр parks_nearest, ponds_nearest

# %% [markdown]
# Заполним количество ближайших парков и прудов путем округления значения в ближайших парках и прудах в 3 км, значения из parks_around3000, ponds_around3000 округлим при изменении типов ниже

# %%
df['parks_nearest'] = df["parks_around3000"].apply(lambda x: round(x))

# %%
df['ponds_nearest'] = df["ponds_around3000"].apply(lambda x: round(x))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20441 entries, 1 to 23697
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          20441 non-null  int64
#  1   last_price            20441 non-null  float64
#  2   total_area            20441 non-null  float64
#  3   first_day_exposition  20441 non-null  datetime64[ns]
#  4   rooms                 20441 non-null  int64
#  5   ceiling_height        20441 non-null  float64
#  6   floors_total          20441 non-null  float64
#  7   living_area           18766 non-null  float64
#  8   floor                 20441 non-null  int64
#  9   is_apartment          20441 non-null  object
#  10  studio                20441 non-null  bool
#  11  open_plan             20441 non-null  bool
#  12  kitchen_area          20441 non-null  float64
#  13  balcony               20441 non-null  float64
# ...

# %% [markdown]
# ### Произведем категоризацию данных

# %% [markdown]
# #### Обработаем параметр living_area

# %% [markdown]
# Для того что бы избавиться от пропусков заполним из медианным значением основываясь на группы, сформированные по количеству комнат, размерам общей площади, которые нужно дополнительно категоризировать, студия или нет.

# %%
df['living_area'].describe()
# Out:
# count    18766.00000
# mean        33.57483
# std         21.28630
# min         14.00000
# 25%         18.30000
# 50%         30.00000
# 75%         41.60000
# max        409.70000
# Name: living_area, dtype: float64

# %%
def category_area (area):
    if area <=20:
        return 'small'
    elif 20<area<=40:
        return 'middel'
    elif 40 < area <=80:
        return 'big'
    return 'large'

# %%
df['category_living_area'] = df['total_area'].apply(category_area)

# %%
def category_rooms (rooms):
    if rooms <=1:
        return 'small'
    elif 1<rooms<=2:
        return 'middel'
    elif 2 < rooms <=3:
        return 'big'
    return 'large'

# %%
df['category_rooms'] = df['rooms'].apply(category_rooms)

# %%
living_pivot_table = df.pivot_table(index = ["category_living_area","category_rooms"],
                                       columns = 'studio',
                                       values = 'living_area', aggfunc = 'median' ).dropna(axis=0)
print(living_pivot_table)
# Out:
# studio                               False   True
# category_living_area category_rooms
# big                  big             42.60  43.000
#                      large           48.60  45.200
#                      middel          30.20  31.000
#                      small           18.62  19.850
# large                big             53.90  60.000
#                      large           77.00  81.000
#                      middel          42.31  44.645
#                      small           40.80  60.500
# middel               middel          24.00  26.000
#                      small           17.10  18.000
# small                small           14.00  15.400

# %% [markdown]
# #### Обработаем airports_nearest

# %%
df['airports_nearest'].describe()
# Out:
# count    15775.00000
# mean     28831.87537
# std      12702.14503
# min          0.00000
# 25%      18495.50000
# 50%      26767.00000
# 75%      37407.00000
# max      84869.00000
# Name: airports_nearest, dtype: float64

# %%
def category_airports_nearest (distance):
    if distance <=10000:
        return 'small'
    elif 10000<distance<=20000:
        return 'middel'
    elif 20000 < distance <=30000:
        return 'big'
    else:
        return 'large'

# %%
df['category_airports_nearest'] = df['airports_nearest'].apply(category_airports_nearest)

# %%
airports_nearest_pivot_table = df.pivot_table(
    index = ['locality_name','category_airports_nearest'],
    values = "airports_nearest",
    aggfunc = 'median'
).dropna(axis=0)
print(airports_nearest_pivot_table)
# Out:
#                                               airports_nearest
# locality_name      category_airports_nearest
# unknown            big                                 22041.0
#                    large                               36994.0
#                    middel                              11206.0
# Зеленогорск        large                               72284.0
# Колпино            big                                 26169.0
# ...                                                        ...
# посёлок Стрельна   big                                 28317.0
# посёлок Усть-Ижора big                                 26510.5
# посёлок Шушары     big                                 23581.5
#                    middel                              13931.0
#                    small                                9914.0
#
# [39 rows x 1 columns]

# %% [markdown]
# #### Обработаем city_centers_nearest

# %%
df['city_centers_nearest'].describe()
# Out:
# count    15797.00000
# mean     14284.72640
# std       8564.53865
# min        208.00000
# 25%       9461.00000
# 50%      13151.00000
# 75%      16376.00000
# max      65968.00000
# Name: city_centers_nearest, dtype: float64

# %%
def category_city_centers_nearest (distance_centers):
    if distance_centers <=10000:
        return 'small'
    elif 10000<distance_centers<=20000:
        return 'middel'
    elif 20000 < distance_centers <=30000:
        return 'big'
    else:
        return 'large'

# %%
df['category_city_centers_nearest'] = df['city_centers_nearest'].apply(category_city_centers_nearest)

# %%
city_centers_nearest_pivot_table = df.pivot_table(
    index = ['locality_name','category_city_centers_nearest'],
    values = "city_centers_nearest",
    aggfunc = 'median'
).dropna(axis=0)
print(city_centers_nearest_pivot_table)
# Out:
#                                                   city_centers_nearest
# locality_name      category_city_centers_nearest
# unknown            big                                         23659.0
#                    large                                       36595.5
#                    middel                                      17369.0
#                    small                                        4604.0
# Зеленогорск        large                                       53383.0
# ...                                                                ...
# посёлок Стрельна   big                                         23506.0
# посёлок Усть-Ижора big                                         28222.5
# посёлок Шушары     big                                         29041.0
#                    large                                       30786.0
#                    middel                                      18465.0
#
# [39 rows x 1 columns]

# %% [markdown]
# ### Создадим общую функцию, с помощью которой будем заполнять пропуски

# %%
def columns_fillna(row, pivot_table,aim_column, index_columns):
    if pd.isnull(row[aim_column]):
        index = (index_columns[0],index_columns[1])
        if index in pivot_table.index:
            return pivot_table.loc[index][0]
        else:
            return df[aim_column].median()
    else:
        return row[aim_column]

# %% [markdown]
# #### Заполним пропуски в 'living_area'

# %%
df['living_area']= df.apply(columns_fillna,
                                  pivot_table = living_pivot_table,
                                  aim_column = 'living_area',
                                  index_columns = ["type_of_flat","type_of_area"],
                                  axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20441 entries, 1 to 23697
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   total_images                   20441 non-null  int64
#  1   last_price                     20441 non-null  float64
#  2   total_area                     20441 non-null  float64
#  3   first_day_exposition           20441 non-null  datetime64[ns]
#  4   rooms                          20441 non-null  int64
#  5   ceiling_height                 20441 non-null  float64
#  6   floors_total                   20441 non-null  float64
#  7   living_area                    20441 non-null  float64
#  8   floor                          20441 non-null  int64
#  9   is_apartment                   20441 non-null  object
#  10  studio                         20441 non-null  bool
#  11  open_plan                      20441 non-null  bool
# ...

# %% [markdown]
# #### Заполним пропуски в 'airports_nearest'

# %%
df['airports_nearest']= df.apply(columns_fillna,
                                  pivot_table = airports_nearest_pivot_table,
                                  aim_column = 'airports_nearest',
                                  index_columns = 'locality_name',
                                  axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20441 entries, 1 to 23697
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   total_images                   20441 non-null  int64
#  1   last_price                     20441 non-null  float64
#  2   total_area                     20441 non-null  float64
#  3   first_day_exposition           20441 non-null  datetime64[ns]
#  4   rooms                          20441 non-null  int64
#  5   ceiling_height                 20441 non-null  float64
#  6   floors_total                   20441 non-null  float64
#  7   living_area                    20441 non-null  float64
#  8   floor                          20441 non-null  int64
#  9   is_apartment                   20441 non-null  object
#  10  studio                         20441 non-null  bool
#  11  open_plan                      20441 non-null  bool
# ...

# %% [markdown]
# #### Заполним пропуски в 'city_centers_nearest'

# %%
df['city_centers_nearest']= df.apply(columns_fillna,
                                  pivot_table = city_centers_nearest_pivot_table,
                                  aim_column = 'city_centers_nearest',
                                  index_columns = 'locality_name',
                                  axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20441 entries, 1 to 23697
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   total_images                   20441 non-null  int64
#  1   last_price                     20441 non-null  float64
#  2   total_area                     20441 non-null  float64
#  3   first_day_exposition           20441 non-null  datetime64[ns]
#  4   rooms                          20441 non-null  int64
#  5   ceiling_height                 20441 non-null  float64
#  6   floors_total                   20441 non-null  float64
#  7   living_area                    20441 non-null  float64
#  8   floor                          20441 non-null  int64
#  9   is_apartment                   20441 non-null  object
#  10  studio                         20441 non-null  bool
#  11  open_plan                      20441 non-null  bool
# ...

# %% [markdown]
# ### Изменение типов данных

# %%
import numpy as np
int_types = ["uint8", "int8", "int16"]
for it in int_types:
    print(np.iinfo(it))
# Out:
# Machine parameters for uint8
# ---------------------------------------------------------------
# min = 0
# max = 255
# ---------------------------------------------------------------
#
# Machine parameters for int8
# ---------------------------------------------------------------
# min = -128
# max = 127
# ---------------------------------------------------------------
#
# Machine parameters for int16
# ---------------------------------------------------------------
# min = -32768
# max = 32767
# ---------------------------------------------------------------

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20441 entries, 1 to 23697
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   total_images                   20441 non-null  int64
#  1   last_price                     20441 non-null  float64
#  2   total_area                     20441 non-null  float64
#  3   first_day_exposition           20441 non-null  datetime64[ns]
#  4   rooms                          20441 non-null  int64
#  5   ceiling_height                 20441 non-null  float64
#  6   floors_total                   20441 non-null  float64
#  7   living_area                    20441 non-null  float64
#  8   floor                          20441 non-null  int64
#  9   is_apartment                   20441 non-null  object
#  10  studio                         20441 non-null  bool
#  11  open_plan                      20441 non-null  bool
# ...

# %%
for dtype in ['float','int','object']:
    selected_dtype = df.select_dtypes(include=[dtype])
    mean_usage_b = selected_dtype.memory_usage(deep=True).mean()
    mean_usage_mb = mean_usage_b / 1024 ** 2
    print("Average memory usage for {} columns: {:03.2f} MB".format(dtype,mean_usage_mb))
# Out:
# Average memory usage for float columns: 0.16 MB
# Average memory usage for int columns: 0.16 MB
# Average memory usage for object columns: 1.19 MB

# %%
def mem_usage(pandas_obj):
    if isinstance(pandas_obj,pd.DataFrame):
        usage_b = pandas_obj.memory_usage(deep=True).sum()
    else: # исходим из предположения о том, что если это не DataFrame, то это Series
        usage_b = pandas_obj.memory_usage(deep=True)
    usage_mb = usage_b / 1024 ** 2 # преобразуем байты в мегабайты
    return "{:03.2f} MB".format(usage_mb)

df_int = df.select_dtypes(include=['int'])
converted_int = df_int.apply(pd.to_numeric,downcast='unsigned')

print(mem_usage(df_int))
print(mem_usage(converted_int))

compare_ints = pd.concat([df_int.dtypes,converted_int.dtypes],axis=1)
compare_ints.columns = ['before','after']
compare_ints.apply(pd.Series.value_counts)
# Out:
# 0.94 MB
# 0.25 MB
#        before  after
# uint8     NaN    5.0
# int64     5.0    NaN

# %%
df_float = df.select_dtypes(include=['float'])
converted_float = df_float.apply(pd.to_numeric,downcast='float')

print(mem_usage(df_float))
print(mem_usage(converted_float))

compare_floats = pd.concat([df_float.dtypes,converted_float.dtypes],axis=1)
compare_floats.columns = ['before','after']
compare_floats.apply(pd.Series.value_counts)
# Out:
# 2.03 MB
# 1.09 MB
#          before  after
# float32     NaN   12.0
# float64    12.0    NaN

# %%
optimized_df = df.copy()

optimized_df[converted_int.columns] = converted_int
optimized_df[converted_float.columns] = converted_float

print(mem_usage(df))
print(mem_usage(optimized_df))
# Out:
# 11.15 MB
# 9.53 MB

# %%
df_obj = df.select_dtypes(include=['object']).copy()
df_obj.describe()
# Out:
#        is_apartment    locality_name category_living_area category_rooms  \
# count         20441            20441                20441          20441
# unique            2              331                    4              4
# top           False  Санкт-Петербург                  big          small
# freq          20403            13577                12088           7426
#
#        category_airports_nearest category_city_centers_nearest
# count                      20441                         20441
# unique                         4                             4
# top                        large                        middel
# freq                       11448                          9204

# %% [markdown]
# В столбце locality_name имеется 17023 значений. Среди них всего 323 уникальных.
#
# В столбцах category_living_area,category_rooms,	category_airports_nearest,category_city_centers_nearest имеется 17023 значений. Среди них всего 4 уникальных.
#
# В столбце flat_category имеется 17023 значений. Среди них всего 3 уникальных.

# %%
converted_obj = pd.DataFrame()

for col in df_obj.columns:
    num_unique_values = len(df_obj[col].unique())
    num_total_values = len(df_obj[col])
    if num_unique_values / num_total_values < 0.5:
        converted_obj.loc[:,col] = df_obj[col].astype('category')
    else:
        converted_obj.loc[:,col] = df_obj[col]

# %%
print(mem_usage(df_obj))
print(mem_usage(converted_obj))

compare_obj = pd.concat([df_obj.dtypes,converted_obj.dtypes],axis=1)
compare_obj.columns = ['before','after']
compare_obj.apply(pd.Series.value_counts)
# Out:
# 8.30 MB
# 0.35 MB
#           before  after
# object       6.0    NaN
# category     NaN    4.0
# category     NaN    1.0
# category     NaN    1.0

# %% [markdown]
# Как видно, сначала потреблялось 8.16 мегабайт памяти, а после оптимизации — лишь 0.3 мегабайт, что означает 96% улучшение этого показателя.

# %%
optimized_df[converted_obj.columns] = converted_obj

mem_usage(optimized_df)
# Out:
# '1.58 MB'

# %%
df = optimized_df

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20441 entries, 1 to 23697
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   total_images                   20441 non-null  uint8
#  1   last_price                     20441 non-null  float32
#  2   total_area                     20441 non-null  float32
#  3   first_day_exposition           20441 non-null  datetime64[ns]
#  4   rooms                          20441 non-null  uint8
#  5   ceiling_height                 20441 non-null  float32
#  6   floors_total                   20441 non-null  float32
#  7   living_area                    20441 non-null  float32
#  8   floor                          20441 non-null  uint8
#  9   is_apartment                   20441 non-null  category
#  10  studio                         20441 non-null  bool
#  11  open_plan                      20441 non-null  bool
# ...

# %% [markdown]
# Оптимизация и изменение типов данных прошла успешно! Занимаемый объем стал 1.5 МВ вместо 11.2 М, улучшение аж на 86% !

# %% [markdown]
# Изменяем тип данных для возможности дальнейшего анализа

# %% [markdown]
# При сбросе индекса старый индекс добавляется в качестве столбца и используется новый последовательный индекс, поэтому используем параметр drop, чтобы избежать добавления старого индекса в качестве столбца

# %%
df.reset_index(drop=True)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                 7   3350000.0       40.40           2018-12-04      1
# 1                10   5196000.0       56.00           2015-08-20      2
# 2                 0  64900000.0      159.00           2015-07-24      3
# 3                 2  10000000.0      100.00           2018-06-19      2
# 4                10   2890000.0       30.40           2018-09-10      1
# ...             ...         ...         ...                  ...    ...
# 20436            11   9470000.0       72.90           2016-10-13      2
# 20437             2   1350000.0       30.00           2017-07-07      1
# 20438             9   4600000.0       62.40           2016-08-05      3
# 20439            14   3100000.0       59.00           2018-01-15      3
# 20440            13  11475000.0       76.75           2017-03-28      2
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %% [markdown]
# ### Удаление дубликатов

# %%
df.drop_duplicates()
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 1                 7   3350000.0       40.40           2018-12-04      1
# 2                10   5196000.0       56.00           2015-08-20      2
# 3                 0  64900000.0      159.00           2015-07-24      3
# 4                 2  10000000.0      100.00           2018-06-19      2
# 5                10   2890000.0       30.40           2018-09-10      1
# ...             ...         ...         ...                  ...    ...
# 23691            11   9470000.0       72.90           2016-10-13      2
# 23692             2   1350000.0       30.00           2017-07-07      1
# 23693             9   4600000.0       62.40           2016-08-05      3
# 23695            14   3100000.0       59.00           2018-01-15      3
# 23697            13  11475000.0       76.75           2017-03-28      2
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Дублекатов не обнаружино.

# %% [markdown]
# ### Вывод

# %% [markdown]
# Предобработка данных закончена. Были заполнены пропуски, изменены типы данных и удалены дубликаты.

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# ###  Цена квадратного метра

# %%
def price_per_meter(row):
    return row["last_price"]/row['total_area']

# %%
df['price_per_meter'] = df.apply(price_per_meter,axis = 1)

# %% [markdown]
# ###  День недели, месяц и год публикации объявления

# %%
df['day_exposition'] = df['first_day_exposition'].dt.day
df['month_exposition'] = df['first_day_exposition'].dt.month
df['year_exposition'] = df['first_day_exposition'].dt.year

# %% [markdown]
# ### Этаж квартиры

# %%
def flat_category(floor):
    if floor['floor'] == 1:
        return 'первый'
    elif floor['floors_total'] == floor['floor']:
        return 'последний'
    else:
        return 'другой'

# %%
df['flat_category'] = df.apply(flat_category,axis = 1)

# %% [markdown]
# ### Cоотношение жилой и общей площади

# %%
def living_area_to_total_area(row):
    return row['living_area']/row['total_area']

# %%
df['living_area_to_total_area'] = df.apply(living_area_to_total_area,axis = 1)

# %% [markdown]
# ### Отношение площади кухни к общей

# %%
def kitchen_area_to_total_area(row):
    return row['kitchen_area']/row['total_area']

# %%
df['kitchen_area_to_total_area'] = df.apply(kitchen_area_to_total_area,axis = 1)

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Проанализируем выбросы в столбцах.

# %% [markdown]
# #### Столбец 'last_price'

# %% [markdown]
# Будем использовать Boxplots для обнаружения и визуализации выбросов, присутствующих в наборе данных.
#
# Коробки изображают распределение данных с точки зрения квартилей и состоит из следующих компонентов
#
# Q1-25%
#
# Q2-50%
#
# Q3-75%
#
# Нижняя граница/усы
#
# Верхний усы/граница

# %%
df.boxplot('last_price');

# %% [markdown]
# Как видно выше, столбец содержит выбросы, которые лежат над нижней границей.
#
# Используя IQR, мы можем следовать приведенному ниже подходу для замены выбросов в нулевое значение:
#
# Рассчитайть первый и третий квартиль (Q1 и Q3).
#
# Кроме того, оценить межквартирный диапазон, IQR-Q1
#
# Оценить нижнюю границу, ниже * 1.5
#
# Оценить верхнюю границу, Верхний * 1.5.
#
# Заменить точки данных, которые лежат за пределами нижней и верхней границы с Нулевое значение

# %%
for x in ['last_price']:
    q75,q25 = np.percentile(df.loc[:,x],[75,25])
    intr_qr = q75-q25

    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)

    df.loc[df[x] < min,x] = np.nan
    df.loc[df[x] > max,x] = np.nan

# %%
df['last_price'].isnull().sum()
# Out:
# 1678

# %% [markdown]
# Заметим, что столбец last_price содержит 1678 пропусков или по-другому выбросы.

# %%
df = df.dropna(axis = 0)

# %% [markdown]
# ####  Столбец 'ceiling_height'

# %%
df.boxplot('ceiling_height')
# Out:
# <AxesSubplot:>

# %%
for x in ['ceiling_height']:
    q75,q25 = np.percentile(df.loc[:,x],[75,25])
    intr_qr = q75-q25

    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)

    df.loc[df[x] < min,x] = np.nan
    df.loc[df[x] > max,x] = np.nan
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df['ceiling_height'].isnull().sum()
# Out:
# 180

# %%
df = df.dropna(axis = 0)

# %% [markdown]
# ####  Столбец 'days_exposition'

# %%
df.boxplot('days_exposition');

# %%
for x in ['days_exposition']:
    q75,q25 = np.percentile(df.loc[:,x],[75,25])
    intr_qr = q75-q25

    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)

    df.loc[df[x] < min,x] = np.nan
    df.loc[df[x] > max,x] = np.nan

# %%
df['days_exposition'].isnull().sum()
# Out:
# 1560

# %%
df = df.dropna(axis = 0)

# %% [markdown]
# #### Вывод

# %% [markdown]
# Мы встретили большое количество выбросов и пропущенных значений. Все проблемные места были исправлены

# %% [markdown]
# ### Проведем исследовательский анализ данных

# %% [markdown]
# #### Построим гистограмму по значениям из столбца 'total_area'

# %%
ax = df.hist(column='total_area', bins=15, grid=False, figsize=(15,5), color='#86bf91', zorder=2, rwidth=0.9)

ax = ax[0]
for x in ax:

    # Despine
    x.spines['right'].set_visible(False)
    x.spines['top'].set_visible(False)
    x.spines['left'].set_visible(False)

    # Switch off ticks
    x.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")
     # Draw horizontal axis lines
    vals = x.get_yticks()
    for tick in vals:
        x.axhline(y=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

    # Remove title
    x.set_title("")

    # Set x-axis label
    x.set_xlabel("total_area (Meters)", labelpad=20, weight='bold', size=12)

    # Set y-axis label
    x.set_ylabel("Sessions", labelpad=20, weight='bold', size=12)

# %% [markdown]
# Из гистограммы явно видно, что наиболее популярная площадь квартир находится в диапазоне 45-50 кв.м

# %% [markdown]
# #### Построим гистограмму по значениям из столбца 'last_price'

# %%
ax = df.hist(column='last_price', bins=15, grid=False, figsize=(15,5), color='#86bf91', zorder=2, rwidth=0.9)

ax = ax[0]
for x in ax:

    # Despine
    x.spines['right'].set_visible(False)
    x.spines['top'].set_visible(False)
    x.spines['left'].set_visible(False)

    # Switch off ticks
    x.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")
     # Draw horizontal axis lines
    vals = x.get_yticks()
    for tick in vals:
        x.axhline(y=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

    # Remove title
    x.set_title("")

    # Set x-axis label
    x.set_xlabel("last_price", labelpad=20, weight='bold', size=12)

    # Set y-axis label
    x.set_ylabel("Sessions", labelpad=20, weight='bold', size=12)

# %% [markdown]
# #### Построим гистограмму по значениям из столбца 'rooms'

# %%
ax = df.hist(column='rooms', bins=15, grid=False, figsize=(15,5), color='#86bf91', zorder=2, rwidth=0.9)

ax = ax[0]
for x in ax:

    # Despine
    x.spines['right'].set_visible(False)
    x.spines['top'].set_visible(False)
    x.spines['left'].set_visible(False)

    # Switch off ticks
    x.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")
     # Draw horizontal axis lines
    vals = x.get_yticks()
    for tick in vals:
        x.axhline(y=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

    # Remove title
    x.set_title("")

    # Set x-axis label
    x.set_xlabel("rooms", labelpad=20, weight='bold', size=12)

    # Set y-axis label
    x.set_ylabel("Sessions", labelpad=20, weight='bold', size=12)

# %% [markdown]
# ##### Вывод

# %% [markdown]
# Из гистограммы выдно, что наибольшей популярностью пользуются однокомнатные или двухкомнатные квартиры

# %% [markdown]
# #### Построим гистограмму по значениям из столбца 'ceiling_height'

# %%
ax = df.hist(column='ceiling_height', bins=15, grid=False, figsize=(15,5), color='#86bf91', zorder=2, rwidth=0.9)

ax = ax[0]
for x in ax:

    # Despine
    x.spines['right'].set_visible(False)
    x.spines['top'].set_visible(False)
    x.spines['left'].set_visible(False)

    # Switch off ticks
    x.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")
     # Draw horizontal axis lines
    vals = x.get_yticks()
    for tick in vals:
        x.axhline(y=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

    # Remove title
    x.set_title("")

    # Set x-axis label
    x.set_xlabel("ceiling_height", labelpad=20, weight='bold', size=12)

    # Set y-axis label
    x.set_ylabel("Sessions", labelpad=20, weight='bold', size=12)

# %% [markdown]
# ##### Вывод

# %% [markdown]
# Из гисторграммы выидно, что основная часть квартир имеют потолки до 2.2м, но также часто встречаются квартиры с потолками от 2.5 до 2.8 метров, реже более 2.8 м

# %% [markdown]
# #### Построим гистограмму по значениям из столбца 'first_day_exposition'

# %%
ax = df.hist(column='first_day_exposition', bins=15, grid=False, figsize=(15,5), color='#86bf91', zorder=2, rwidth=0.9)

ax = ax[0]
for x in ax:

    # Despine
    x.spines['right'].set_visible(False)
    x.spines['top'].set_visible(False)
    x.spines['left'].set_visible(False)

    # Switch off ticks
    x.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")
     # Draw horizontal axis lines
    vals = x.get_yticks()
    for tick in vals:
        x.axhline(y=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

    # Remove title
    x.set_title("")

    # Set x-axis label
    x.set_xlabel("first_day_exposition", labelpad=20, weight='bold', size=12)

    # Set y-axis label
    x.set_ylabel("Sessions", labelpad=20, weight='bold', size=12)

# %% [markdown]
# ##### Вывод

# %% [markdown]
# Пик роста выставления объявлений приходится на осень 2017 года по середину зимы 2018 года

# %% [markdown]
# #### Построим гистограмму по значениям из столбца 'days_exposition'

# %%
ax = df.hist(column='days_exposition', bins=15, grid=False, figsize=(15,5), color='#86bf91', zorder=2, rwidth=0.9)

ax = ax[0]
for x in ax:

    # Despine
    x.spines['right'].set_visible(False)
    x.spines['top'].set_visible(False)
    x.spines['left'].set_visible(False)

    # Switch off ticks
    x.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")
     # Draw horizontal axis lines
    vals = x.get_yticks()
    for tick in vals:
        x.axhline(y=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

    # Remove title
    x.set_title("")

    # Set x-axis label
    x.set_xlabel("days_exposition", labelpad=20, weight='bold', size=12)

    # Set y-axis label
    x.set_ylabel("Sessions", labelpad=20, weight='bold', size=12)

# %% [markdown]
# ##### Вывод по гистограмме

# %% [markdown]
# Здесь мы видим, что большая часть недвижимости продается в период между 15 - 70 днями с даты появления объявления на площадке. Но так же есть достаточно весомое количество объявлений, которое было в продаже больше года

# %% [markdown]
# ##### Посчитаем медиану и среднее значение

# %%
df['days_exposition'].median()
# Out:
# 79.0

# %% [markdown]
# По этим данным можно сделать вывод, что обычно объявления закрываются за 79 дней

# %%
df['days_exposition'].mean()
# Out:
# 121.22352

# %% [markdown]
# А по среднему значению видно, что число намного больше ~121 день, это происходит из-за существующих объявлений, которые закрылись более, чем за полгода

# %%
df['days_exposition'].describe()
# Out:
# count    17023.00000
# mean       121.22352
# std        113.80301
# min          1.00000
# 25%         39.00000
# 50%         79.00000
# 75%        174.00000
# max        479.00000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Заметим:
#
# <=39 дней - быстрая продажа
# , >= 174 дней - долгая продажа

# %% [markdown]
# ### Изучим кореляцию цен от других параметров

# %% [markdown]
# #### Зависимость цены от параметров квартиры

# %%
print(df[["total_area","rooms","flat_category",'city_centers_nearest','last_price']].corr())
pd.plotting.scatter_matrix(df[["total_area","rooms","flat_category",'city_centers_nearest','last_price']],figsize=(15,15))
# Out:
#                       total_area    rooms  city_centers_nearest  last_price
# total_area               1.00000  0.80266              -0.07956     0.68777
# rooms                    0.80266  1.00000              -0.05271     0.44703
# city_centers_nearest    -0.07956 -0.05271               1.00000    -0.20780
# last_price               0.68777  0.44703              -0.20780     1.00000
# array([[<AxesSubplot:xlabel='total_area', ylabel='total_area'>,
#         <AxesSubplot:xlabel='rooms', ylabel='total_area'>,
#         <AxesSubplot:xlabel='city_centers_nearest', ylabel='total_area'>,
#         <AxesSubplot:xlabel='last_price', ylabel='total_area'>],
#        [<AxesSubplot:xlabel='total_area', ylabel='rooms'>,
#         <AxesSubplot:xlabel='rooms', ylabel='rooms'>,
#         <AxesSubplot:xlabel='city_centers_nearest', ylabel='rooms'>,
#         <AxesSubplot:xlabel='last_price', ylabel='rooms'>],
#        [<AxesSubplot:xlabel='total_area', ylabel='city_centers_nearest'>,
# ...

# %% [markdown]
# Из анализа видно, что цена зависит от площади и от удалености от центра

# %% [markdown]
# #### Зависимость цены от даты размещения объявления

# %%
print(df[['day_exposition','month_exposition','year_exposition','last_price']].corr())
pd.plotting.scatter_matrix(df[['day_exposition','month_exposition','year_exposition','last_price']],figsize=(15,15))
# Out:
#                   day_exposition  month_exposition  year_exposition  \
# day_exposition           1.00000          -0.00801         -0.05022
# month_exposition        -0.00801           1.00000         -0.22963
# year_exposition         -0.05022          -0.22963          1.00000
# last_price               0.00305           0.00654          0.00753
#
#                   last_price
# day_exposition       0.00305
# month_exposition     0.00654
# year_exposition      0.00753
# last_price           1.00000
# array([[<AxesSubplot:xlabel='day_exposition', ylabel='day_exposition'>,
#         <AxesSubplot:xlabel='month_exposition', ylabel='day_exposition'>,
#         <AxesSubplot:xlabel='year_exposition', ylabel='day_exposition'>,
#         <AxesSubplot:xlabel='last_price', ylabel='day_exposition'>],
#        [<AxesSubplot:xlabel='day_exposition', ylabel='month_exposition'>,
#         <AxesSubplot:xlabel='month_exposition', ylabel='month_exposition'>,
# ...

# %%
static = df.pivot_table(index = ['day_exposition','month_exposition','year_exposition'],
                                                     values = ['last_price'],
                                                     aggfunc = ["count","mean"])

# %%
ax = static.hist(column='count', bins=15, grid=False, figsize=(15,5), color='#86bf91', zorder=2, rwidth=0.9)

ax = ax[0]
for x in ax:

    # Despine
    x.spines['right'].set_visible(False)
    x.spines['top'].set_visible(False)
    x.spines['left'].set_visible(False)

    # Switch off ticks
    x.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")
     # Draw horizontal axis lines
    vals = x.get_yticks()
    for tick in vals:
        x.axhline(y=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

    # Remove title
    x.set_title("")

    # Set x-axis label
    x.set_xlabel("count", labelpad=20, weight='bold', size=12)

    # Set y-axis label
    x.set_ylabel("Sessions", labelpad=20, weight='bold', size=12)

# %%
ax = static.hist(column='mean', bins=15, grid=False, figsize=(15,5), color='#86bf91', zorder=2, rwidth=0.9)

ax = ax[0]
for x in ax:

    # Despine
    x.spines['right'].set_visible(False)
    x.spines['top'].set_visible(False)
    x.spines['left'].set_visible(False)

    # Switch off ticks
    x.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")
     # Draw horizontal axis lines
    vals = x.get_yticks()
    for tick in vals:
        x.axhline(y=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

    # Remove title
    x.set_title("")

    # Set x-axis label
    x.set_xlabel("mean", labelpad=20, weight='bold', size=12)

    # Set y-axis label
    x.set_ylabel("Sessions", labelpad=20, weight='bold', size=12)

# %% [markdown]
# Отсюда видно, что цена квартиры не зависит от даты размещения объявления

# %% [markdown]
# ### Проанализируем среднюю цену за метр в топ-10 городах

# %%
top_10_locality_name = df.pivot_table(index = 'locality_name',
                                                     values = ["price_per_meter"],
                                                     aggfunc = ["count","mean"])

# %%
top_10_locality_name.columns = ['count', 'mean']

# %%
top_10_locality_name.sort_values(by = "count",inplace = True,ascending = False)

# %%
top_10_locality_name.head(10)
# Out:
#                    count          mean
# locality_name
# Санкт-Петербург    10821  103791.25710
# посёлок Мурино       477   85720.20600
# посёлок Шушары       383   77535.75494
# Всеволожск           302   66590.62525
# Колпино              289   74427.97231
# посёлок Парголово    284   88708.62191
# деревня Кудрово      264   92395.64494
# Пушкин               254   99044.77906
# Гатчина              241   68012.20181
# Выборг               187   56656.15453

# %% [markdown]
# Видно, что самая высокая цена в СПБ за метр

# %% [markdown]
# ### Изучение предложений квартир в СПБ

# %% [markdown]
# #### Добавим столбец с расстоянием до центра в км

# %%
df['city_centers_nearest_km'] = df['city_centers_nearest']/1000

# %%
df['city_centers_nearest_km'].isnull().sum()
# Out:
# 0

# %%
df['city_centers_nearest_km'].astype('int')
# Out:
# 1        18
# 4         8
# 5        13
# 6        19
# 8        13
#          ..
# 23689    16
# 23690     6
# 23692    13
# 23693    34
# 23695    13
# Name: city_centers_nearest_km, Length: 17023, dtype: int64

# %%
St_Petersburg_flat = df.query('locality_name == "Санкт-Петербург"').pivot_table(index = 'city_centers_nearest_km', values = 'price_per_meter', aggfunc = 'mean')

# %%
St_Petersburg_flat['km'] = St_Petersburg_flat.index
St_Petersburg_flat.reset_index(drop = True,inplace = True)

# %%
St_Petersburg_flat.plot(figsize = (15,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# По диаграмме видно, что резкий перепад происходит ~8 км. Поэтому будем считать центр - радиус 8 км

# %% [markdown]
# ### Найдем корреляцию для недвижимости в центре Питера

# %%
SPB_in_city_center =  df.query('city_centers_nearest_km < 9')

# %%
print(SPB_in_city_center[['rooms',
                                          'floor', 
                                          'city_centers_nearest',
                                          'first_day_exposition',
                                          'last_price']].corr())

pd.plotting.scatter_matrix(SPB_in_city_center[['rooms',
                                          'floor', 
                                          'city_centers_nearest',
                                          'first_day_exposition',
                                          'last_price']],figsize=(15,15))
# Out:
#                         rooms    floor  city_centers_nearest  last_price
# rooms                 1.00000 -0.17044              -0.21157     0.48132
# floor                -0.17044  1.00000               0.25849     0.12237
# city_centers_nearest -0.21157  0.25849               1.00000    -0.23295
# last_price            0.48132  0.12237              -0.23295     1.00000
# array([[<AxesSubplot:xlabel='rooms', ylabel='rooms'>,
#         <AxesSubplot:xlabel='floor', ylabel='rooms'>,
#         <AxesSubplot:xlabel='city_centers_nearest', ylabel='rooms'>,
#         <AxesSubplot:xlabel='last_price', ylabel='rooms'>],
#        [<AxesSubplot:xlabel='rooms', ylabel='floor'>,
#         <AxesSubplot:xlabel='floor', ylabel='floor'>,
#         <AxesSubplot:xlabel='city_centers_nearest', ylabel='floor'>,
#         <AxesSubplot:xlabel='last_price', ylabel='floor'>],
#        [<AxesSubplot:xlabel='rooms', ylabel='city_centers_nearest'>,
# ...

# %% [markdown]
# Можно сделать вывод, что цена в СПБ зависит от количества комнат и удалености от центра.

# %% [markdown]
# #### Посморим распределения по отдельным велечинам

# %%
ax = SPB_in_city_center.hist(column='last_price', bins=30, grid=False, figsize=(15,5), color='#86bf91', zorder=2, rwidth=0.9)

ax = ax[0]
for x in ax:

    # Despine
    x.spines['right'].set_visible(False)
    x.spines['top'].set_visible(False)
    x.spines['left'].set_visible(False)

    # Switch off ticks
    x.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")
     # Draw horizontal axis lines
    vals = x.get_yticks()
    for tick in vals:
        x.axhline(y=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

    # Remove title
    x.set_title("")

    # Set x-axis label
    x.set_xlabel("last_price", labelpad=20, weight='bold', size=12)

    # Set y-axis label
    x.set_ylabel("Sessions", labelpad=20, weight='bold', size=12)

# %%
ax = SPB_in_city_center.hist(column='rooms', bins=30, grid=False, figsize=(15,5), color='#86bf91', zorder=2, rwidth=0.9)

ax = ax[0]
for x in ax:

    # Despine
    x.spines['right'].set_visible(False)
    x.spines['top'].set_visible(False)
    x.spines['left'].set_visible(False)

    # Switch off ticks
    x.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")
     # Draw horizontal axis lines
    vals = x.get_yticks()
    for tick in vals:
        x.axhline(y=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

    # Remove title
    x.set_title("")

    # Set x-axis label
    x.set_xlabel("rooms", labelpad=20, weight='bold', size=12)

    # Set y-axis label
    x.set_ylabel("Sessions", labelpad=20, weight='bold', size=12)

# %%
ax = SPB_in_city_center.hist(column='total_area', bins=30, grid=False, figsize=(15,5), color='#86bf91', zorder=2, rwidth=0.9)

ax = ax[0]
for x in ax:

    # Despine
    x.spines['right'].set_visible(False)
    x.spines['top'].set_visible(False)
    x.spines['left'].set_visible(False)

    # Switch off ticks
    x.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")
     # Draw horizontal axis lines
    vals = x.get_yticks()
    for tick in vals:
        x.axhline(y=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

    # Remove title
    x.set_title("")

    # Set x-axis label
    x.set_xlabel("total_area", labelpad=20, weight='bold', size=12)

    # Set y-axis label
    x.set_ylabel("Sessions", labelpad=20, weight='bold', size=12)

# %%
ax = SPB_in_city_center.hist(column='ceiling_height', bins=30, grid=False, figsize=(15,5), color='#86bf91', zorder=2, rwidth=0.9)

ax = ax[0]
for x in ax:

    # Despine
    x.spines['right'].set_visible(False)
    x.spines['top'].set_visible(False)
    x.spines['left'].set_visible(False)

    # Switch off ticks
    x.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")
     # Draw horizontal axis lines
    vals = x.get_yticks()
    for tick in vals:
        x.axhline(y=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

    # Remove title
    x.set_title("")

    # Set x-axis label
    x.set_xlabel("ceiling_height", labelpad=20, weight='bold', size=12)

    # Set y-axis label
    x.set_ylabel("Sessions", labelpad=20, weight='bold', size=12)

# %%
ax = SPB_in_city_center.hist(column='first_day_exposition', bins=30, grid=False, figsize=(15,5), color='#86bf91', zorder=2, rwidth=0.9)

ax = ax[0]
for x in ax:

    # Despine
    x.spines['right'].set_visible(False)
    x.spines['top'].set_visible(False)
    x.spines['left'].set_visible(False)

    # Switch off ticks
    x.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")
     # Draw horizontal axis lines
    vals = x.get_yticks()
    for tick in vals:
        x.axhline(y=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

    # Remove title
    x.set_title("")

    # Set x-axis label
    x.set_xlabel("first_day_exposition", labelpad=20, weight='bold', size=12)

    # Set y-axis label
    x.set_ylabel("Sessions", labelpad=20, weight='bold', size=12)

# %% [markdown]
# #### Выводы:

# %% [markdown]
# Цена недвижимости:
#
# В отличии от всей выборки, здесь мы видим большой объем более дорогого жилья, которое хорошо видно по перевесу правой части графика
#
# Количество комнат:
#
# относительно всех объявлений здесь виден количественный перевес 2-комнатных квартир
#
# Общая площадь:
#
# График сдвинулся в правую часть, что означает, что в центре преобладает жилье с площадью больше 50 метров
#
# Высота потолков:
#
# На графике более выражены значения 3 метра и 3.2. Но все так же преобладают объекты с высотой потолков до 2.2 метром
#
# День загрузки объявления:
#
# В Питере основной период объявлений был короче и длился около года с осени 2017 года по осень 2018

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Предоставленные данные были достаточно грязными, но после очистки мы смогли их проанализировать и пришли к следующим выводам:
#
# Цена зависит от общей площади и удаления от центра
#
# В центре Питера общая площадь меньше влияет на цену, в отличии от количества комнат, которые выходят на первых план
#
# Основной объем объявлений выл вывешен в период 2017 - 2019
#
# Большее количество квартир имеют высоту потолку не превосходящую 2.2 метра
#
# Чаще встречаются 1-комнатные и 2-комнатные квартиры
#
# По большей части объекты продаются в течение 79-120 дней
